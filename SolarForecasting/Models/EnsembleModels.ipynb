# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/Users/shalikanuwan/Documents/Academics/FYP/ForecastingModelDevelopment/SolarForecasting/Data/filterdSolarGenerationUOM.xlsx')

# %%
data
# Out:
#                 timestamp  solar_energy  temp  humidity  windgust  cloudcover  \
# 0     2022-04-01 00:00:00           0.0  26.1     88.76       9.7        30.0
# 1     2022-04-01 01:00:00           0.0  26.1     83.57      10.8        30.0
# 2     2022-04-01 02:00:00           0.0  25.7     86.52      11.9        61.9
# 3     2022-04-01 03:00:00           0.0  26.1     88.76      13.7        50.0
# 4     2022-04-01 04:00:00           0.0  26.1     88.76      14.8        30.0
# ...                   ...           ...   ...       ...       ...         ...
# 26323 2025-04-01 19:00:00           0.0  29.6     67.09       8.2        50.0
# 26324 2025-04-01 20:00:00           0.0  30.4     70.14       6.7        88.4
# 26325 2025-04-01 21:00:00           0.0  29.5     67.45       7.8        50.0
# 26326 2025-04-01 22:00:00           0.0  29.0     70.49       5.7        90.0
# 26327 2025-04-01 23:00:00           0.0  29.0     77.94       7.2        50.6
#
#        visibility  solarradiation        conditions  solarenergy  \
# 0            10.0             0.0  Partially cloudy          0.0
# 1            10.0             0.0  Partially cloudy          0.0
# 2            18.1             0.0  Partially cloudy          0.0
# 3            10.0             0.0  Partially cloudy          0.0
# 4            10.0             0.0  Partially cloudy          0.0
# ...           ...             ...               ...          ...
# 26323        10.0            25.4  Partially cloudy          0.1
# 26324        12.9             0.0  Partially cloudy          0.0
# 26325        10.0             0.0  Partially cloudy          0.0
# 26326        10.0             0.0  Partially cloudy          0.0
# 26327        12.8             0.0  Partially cloudy          0.0
#
#        Solar_Generation
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 26323          2.000002
# 26324          0.000000
# 26325          0.000000
# 26326          0.000000
# 26327          0.000000
#
# [26328 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = data.drop('conditions',axis=1).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
